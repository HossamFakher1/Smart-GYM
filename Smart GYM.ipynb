# %%
#Smart Gym

# %%
import numpy as np
import cv2
import mediapipe as mp
import time
import math
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp.solutions.pose.Pose()
lmlist=[]

# %%
#اليد
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4=0,0,200,200,0,0,200,200
count=0
count1=0
flag=False
flag1=False
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        #mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            ####################### LEFT ##############################
            if id ==12  :
                x1,y1=cx,cy
                
            if id ==16  :
                x2,y2=cx,cy
            
            
            X = x1 - x2
            cv2.putText(image,"Completed  "+str(count),(20,100),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3) 
            
            if X < 110 and flag :
                count+=1
                flag=False
                
            if X>300 :
                flag=True
                
             ####################### RIGHT ##############################
            cv2.putText(image,"Completed  "+str(count1),(700,100),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3) 
            if id ==11  :
                x3,y3=cx,cy
                
            if id ==15  :
                x4,y4=cx,cy
                
            X1= x4 - x3
            if X1 < 110 and flag1 :
                count1+=1
                flag1=False
                 
                
            if X1>300 :
                flag1=True   
                
                
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
#رفع الحديد
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4,x5,y5=0,0,200,200,0,0,200,200,0,0
count=0
flag=False
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        #mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            if id ==0  :
                x1,y1=cx,cy
            if id ==13  :
                x2,y2=cx,cy
            if id ==14  :
                x3,y3=cx,cy
                
            if id ==15  :
                x4,y4=cx,cy
            if id ==16  :
                x5,y5=cx,cy
            
            
            cv2.putText(image,"Completed  "+str(count),(100,100),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3) 
                
            if y1>y2 and y1 >y3 and flag:
                count+=1
                flag=False
                
            if  y1 < y4 and y1 < y5:
                flag=True  
              
                
            
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
#تمرين اليد 
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4=0,0,200,200,0,0,200,200
count=0
flag=False
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            if id ==15  :
                x1,y1=cx,cy
            if id ==16  :
                x2,y2=cx,cy
            
            
            cv2.putText(image,"Completed  "+str(count),(100,100),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3) 
                
            if abs(x1-x2) < 100  and flag:
                count+=1
                flag=False
                
            if  abs(x1-x2) > 800 :
                flag=True  
              
                
            
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
#البطن
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4=0,0,200,200,0,0,200,200
count=-11
flag=False
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            if id ==11  :
                x1,y1=cx,cy
            if id ==12  :
                x2,y2=cx,cy
            if id ==23  :
                x3,y3=cx,cy
            if id ==24  :
                x4,y4=cx,cy
            
            cv2.putText(image,"Completed  "+str(count),(100,100),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3)  
            
            
            if (abs(x1-x3) < 50 or abs(x2-x4) < 50) and flag :
                count+=1
                flag=False
                
            if (abs(y1-y3) < 50 or abs(y2-y4) < 50) :
                flag=True  
            
            
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
#الضفط
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4=0,0,200,200,0,0,200,200
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            if id ==11  :
                x1,y1=cx,cy
            if id ==12  :
                x2,y2=cx,cy
            if id ==27  :
                x3,y3=cx,cy
            if id ==28  :
                x4,y4=cx,cy
            
            
        
            if (y1 > y3-100 and y2 > y4- 100) :
                cv2.putText(image,"Completed  ",(200,200),cv2.FONT_HERSHEY_PLAIN,3,(0,255,0),3)  
            else :
                cv2.putText(image,"Not Completed  ",(200,200),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3)  
                
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
#العقله 
cap=cv2.VideoCapture(0)
cap.set(3,1080)
cap.set(4,720)
pTime=0
x1,y1,x2,y2,x3,y3,x4,y4,x5,y5=0,0,200,200,0,0,200,200,0,0
count=0
flag=False
while True:
    ret,image=cap.read()
    if ret==False :
        print(True)
        break
        
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    rows, cols, _ = image.shape
    
    if results.pose_landmarks:
        mp_drawing.draw_landmarks( image, results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
        for id , lm in enumerate(results.pose_landmarks.landmark):
            cx,cy=int(lm.x*cols) , int(lm.y * rows)
            
            if id ==10  :
                x1,y1=cx,cy
            if id ==15  :
                x2,y2=cx,cy
            if id ==16  :
                x3,y3=cx,cy
            
            
            cv2.putText(image,"Completed  "+str(count),(100,100),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3) 
                
            if y1 < y2 and y1 < y3 and flag:
                count+=1
                flag=False
                
            if  y1 > y2 and y1 > y3:
                flag=True  
              
                
            
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cTime=time.time()
    fps=1/(cTime-pTime)
    pTime=cTime
    cv2.putText(image,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(0,0,255),3)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(1) & 0xFF == 27:
      break
    
cap.release()
cv2.destroyAllWindows()

# %%
# Out:
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
